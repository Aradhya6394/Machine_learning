# %% [markdown]
# # Working with Json

# %%
import pandas as pd

# %%
pd.read_json("train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# load data from API 
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR")
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWG  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# # Working with SQL

# %% [markdown]
# 1-firstlly we a software called XAMPP.
#
# 2-download this .
#
# 3-open XAAMOP control panel and start Apache(web server) and MYsql(database server).
#
# 4-Run this URL in your Machine localhost/phpmyadmin/.
#
# 5-Create a new database .
#
# 6-Now import the Sql file which you dowmload from kaggle.
#
# 7-Now we have to convert this into pandas dataframe.

# %% [markdown]
# 8-install library - !pip install mysql.connector.

# %% [markdown]
# 9- import mysql.connector

# %% [markdown]
# 10-create a connection through python to your database
# conn=mysql.connector.connect(host="localhost",user="root",password="",database="word")

# %% [markdown]
# pd.read_sql_query("Select * from city",conn)  # you write your code.

# %% [markdown]
# # Working with API

# %% [markdown]
#  * API- application programming interfaces.
#  * in simple words Api a bridge or pipeline between two softwares .

# %%
import requests

# %% [markdown]
# response=requests.get("xyz ") # paste your API

# %% [markdown]
# response.json()["results"]
# * convert into the json formate
# * want only the results column of this dataset

# %% [markdown]
# convert this json formate into dataframe
# res=pd.DataFrame(response.json(['results'])

# %% [markdown]
# * extract the columns which you want .
# res['x','y','z']

# %% [markdown]
# i am working in movies dataset so it has 428 pages so i will do this above work in loop to fetch the data from the api.

# %% [markdown]
# create empty dataframe

# %% [markdown]
# df=pd.Dataframe()

# %% [markdown]
# for i in range(1,429):
#     response=response=requests.get("xyz ")
#     temp_df=pd.Dataframe(response.json()["results"])[['x','y','z']]
#     df=df.append(temp_df,ignore_index=True)

# %% [markdown]
# df.shape

# %% [markdown]
# df.to_csv("name of the dataset")

# %% [markdown]
# * rapid API - you can get free api to create the datasets.
